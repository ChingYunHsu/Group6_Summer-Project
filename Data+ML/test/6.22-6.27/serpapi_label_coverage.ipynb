# %% [markdown]
# # Venue ML Coverage Walkthrough — SerpApi Candidate Selection
#
# **SOP Date**: 2026-06-23
# **Directory**: `Data+ML/test/6.22-6.27/`
#
# **Goal**: Identify which venues have Google Popular Times data (via SerpApi) for supervised ML training.
#
# **Key Constraint**:
# > Search query 用于批量发现 candidates；Place query 只用于最终 label 验证。
# > 不要对每个本地 venue 直接消耗一次 SerpApi 调用。
#
# **Module structure** (post-refactor):
# | Module | Role |
# |---|---|
# | `geo_utils.py` | Haversine distance utilities (`haversine_distance_m`, `haversine_distances_m`) |
# | `serpapi_client.py` | SerpAPI HTTP request with caching + retry (`serpapi_request`, `get_cache_path`) |
# | `healthcare_common.py` | Shared utilities (`resolve_path`, `load_uncovered_healthcare`, `name_similarity`, `require_api_key`, `apply_label_updates`) |
# | `venue_serpapi.py` | Legacy compatibility facade — imports from the modules above; preserves all existing public API |
#
# This notebook imports `venue_serpapi as vs` unchanged — the facade delegates to the new modules internally.
#
# **Workflow**:
# 1. Load & prepare venue data
# 2. Coverage audits (category / district / Citi Bike proximity)
# 3. Priority scoring for candidate selection
# 4. SerpApi Search batch discovery
# 5. Place API validation (limited)
# 6. Label status & ML candidate list
# 7. Coverage audit report & output artifacts

# %%
# Cell 1: Setup & Imports
import sys, os, json
import numpy as np
import pandas as pd
from pathlib import Path
from datetime import datetime, timezone

PROJECT_ROOT = Path('/Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project')
MODULE_DIR  = PROJECT_ROOT / 'Data+ML' / 'test' / '6.22-6.27' / 'src'
OUTPUT_DIR  = PROJECT_ROOT / 'Data+ML' / 'test' / '6.22-6.27' / 'output'
VENUE_FILE  = PROJECT_ROOT / 'Data+ML' / 'test' / '6.8-6.12_DB' / 'tests' / 'output' / 'venues_clean.csv'
COVERAGE_DETAIL = PROJECT_ROOT / 'Data+ML' / 'test' / '6.15-6.20' / 'output' / 'venue_coverage_detail.csv'

sys.path.insert(0, str(MODULE_DIR))
import venue_serpapi as vs

# SerpApi key — set via env var or leave empty for dry-run mode
# ⚠️ 取消下面这行的注释并填入 key 才会切换到 LIVE 模式
# os.environ['SERPAPI_API_KEY'] = 'your_key_here'
SERPAPI_KEY = os.environ.get('SERPAPI_API_KEY', '')
DRY_RUN = not bool(SERPAPI_KEY)

# Ensure output directories exist
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
(OUTPUT_DIR / 'serpapi_raw_responses').mkdir(exist_ok=True)

print(f'Project  : {PROJECT_ROOT}')
print(f'Module   : {MODULE_DIR / "venue_serpapi.py"}')
print(f'Output   : {OUTPUT_DIR}')
print(f'Venues   : {VENUE_FILE}')
print(f'Started  : {datetime.now():%Y-%m-%d %H:%M}')
print(f'SerpApi  : {"LIVE" if not DRY_RUN else "DRY-RUN (no API key)"}')
print(f'Sources  : {len(vs.SERPAPI_SEARCH_CATEGORIES)} categories × {len(vs.DISTRICT_CENTERS)} districts = {len(vs.SERPAPI_SEARCH_CATEGORIES) * len(vs.DISTRICT_CENTERS)} queries')
# Out:
# Project  : /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project
# Module   : /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/src/venue_serpapi.py
# Output   : /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/output
# Venues   : /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.8-6.12_DB/tests/output/venues_clean.csv
# Started  : 2026-06-28 23:42
# SerpApi  : DRY-RUN (no API key)
# Sources  : 4 categories × 4 districts = 16 queries

# %% [markdown]
# ### Cell 1 输出解读
#
# **环境初始化完成**，输出显示：
# - **Project**: 项目根目录
# - **Module**: 引用的 `venue_serpapi` 模块路径
# - **Venues**: 输入数据来源（`venues_clean.csv`）
# - **SerpApi**: `DRY-RUN (no API key)` — 当前为离线模式，不会调用真实 SerpApi
# - **Sources**: 4个类别 × 4个区域 = 16次搜索查询（每次消耗1次 API 配额）
#
# > 💡 **如终端已设置变量但此处仍显示 DRY-RUN**：取消 Cell 1 中 `os.environ['SERPAPI_API_KEY'] = '...'` 的注释，粘贴你的 Key，然后重新执行 Cell 1 即可切换为 `LIVE`。无需重启内核。

# %%
# Cell 2: Load venues
venues, dup_count = vs.load_venues(VENUE_FILE)
print(f'Rows loaded  : {len(venues) + dup_count}')
print(f'Duplicates   : {dup_count}')
print(f'Unique venues: {len(venues)}')
print(f'\nVenue type distribution:')
print(venues['venue_type'].value_counts().to_string())
print(f'\nDistrict distribution:')
print(venues['district'].value_counts().to_string())

# Show in-scope vs out-of-scope
in_scope = venues[~venues['venue_type'].isin(vs.OUT_OF_SCOPE_CATEGORIES)]
print(f'\nIn-scope (for ML): {len(in_scope)}')
print(f'Out-of-scope (AED): {len(venues) - len(in_scope)}')
# Out:
# Rows loaded  : 4838
# Duplicates   : 0
# Unique venues: 4838
#
# Venue type distribution:
# venue_type
# emergencyasset    3279
# healthcare        1086
# restroom           473
#
# District distribution:
# district
# downtown        1467
# midtown_west    1428
# midtown_east    1182
# uptown           703
#
# In-scope (for ML): 1559
# Out-of-scope (AED): 3279

# %%
# Cell 3: Load Citi Bike proximity data (from previous coverage run)
citibike_detail = None
if COVERAGE_DETAIL.exists():
    citibike_detail = pd.read_csv(COVERAGE_DETAIL)
    print(f'Citi Bike detail loaded: {len(citibike_detail)} rows')
    print(f'Columns: {list(citibike_detail.columns[:8])}...')
    print(f'\nNearest distance stats:')
    dist_col = 'citibike_nearest_distance_m'
    if dist_col in citibike_detail.columns:
        print(f'  Median: {citibike_detail[dist_col].median():.0f}m')
        print(f'  P90:    {citibike_detail[dist_col].quantile(0.9):.0f}m')
        print(f'  Max:    {citibike_detail[dist_col].max():.0f}m')
        print(f'  ≤200m:  {(citibike_detail[dist_col] <= 200).sum()} ({(citibike_detail[dist_col] <= 200).mean()*100:.1f}%)')
else:
    print('Citi Bike detail file not found — proximity audit will be skipped')
# Out:
# Citi Bike detail loaded: 4838 rows
# Columns: ['venue_id', 'venue_type', 'district', 'latitude', 'longitude', 'citibike_nearest_source_id', 'citibike_nearest_distance_m', 'citibike_covered_100m']...
#
# Nearest distance stats:
#   Median: 107m
#   P90:    192m
#   Max:    8654169m
#   ≤200m:  4438 (91.7%)

# %% [markdown]
# ---
# ## Coverage Audit #1: By Category

# %%
# Cell 4: Category coverage audit
cat_audit = vs.audit_coverage_by_category(venues)
print('Category Coverage Audit:')
print(cat_audit.to_string(index=False))
print(f'\nNote: emergencyasset ({cat_audit[cat_audit.category=="emergencyasset"].total_venues.values[0]}) = AEDs, out of scope for ML')
# Out:
# Category Coverage Audit:
#       category  total_venues  out_of_scope  ml_eligible  no_data  has_popular_times  checked_count  ml_coverage_pct validation_success_pct
# emergencyasset          3279          3279            0        0                  0              0              0.0                   None
#     healthcare          1086             0            0     1086                  0              0              0.0                   None
#       restroom           473             0            0      473                  0              0              0.0                   None
#
# Note: emergencyasset (3279) = AEDs, out of scope for ML

# %% [markdown]
# ---
# ## Coverage Audit #2: By District

# %%
# Cell 5: District coverage audit
dist_audit = vs.audit_coverage_by_district(venues)
print('District Coverage Audit:')
print(dist_audit.to_string(index=False))
# Out:
# District Coverage Audit:
#     district  total_venues  out_of_scope  ml_eligible  no_data  has_popular_times  checked_count  ml_coverage_pct validation_success_pct
#     downtown          1467           901            0      566                  0              0              0.0                   None
# midtown_east          1182           786            0      396                  0              0              0.0                   None
# midtown_west          1428          1211            0      217                  0              0              0.0                   None
#       uptown           703           381            0      322                  0              0              0.0                   None

# %% [markdown]
# ---
# ## Coverage Audit #3: Citi Bike Proximity

# %%
# Cell 6: Citi Bike proximity audit
cb_audit = vs.audit_citi_bike_proximity(venues, citibike_detail)
if len(cb_audit) > 0:
    print('Citi Bike Proximity Distribution:')
    print(cb_audit.to_string(index=False))
else:
    print('Citi Bike proximity audit skipped (no detail data)')
# Out:
# Citi Bike Proximity Distribution:
#    proximity_bucket  total_venues  in_scope_venues  pct_of_total
#              0-100m          2199              645          45.5
#            100-200m          2239              702          46.3
#            200-300m           303              127           6.3
#            300-500m            26               25           0.5
#               500m+            13                2           0.3
# invalid_coordinates            58               58           1.2

# %% [markdown]
# ---
# ## Priority Scoring
#
# SOP formula:
# ```
# priority_score =
#     category_importance
#   + log(review_count)
#   + rating_quality
#   + distance_to_nearest_bike_station_bonus
#   + geographic_coverage_bonus
#   - duplicate_or_low_confidence_penalty
# ```

# %%
# Cell 7: Calculate priority scores for in-scope venues
in_scope = venues[~venues['venue_type'].isin(vs.OUT_OF_SCOPE_CATEGORIES)].copy()

# Build district label coverage dict (initially all 0 — will update after SerpApi)
district_label_coverage = {d: 0.0 for d in vs.DISTRICT_CENTERS.keys()}

# Merge citibike distance if available
if citibike_detail is not None and 'citibike_nearest_distance_m' in citibike_detail.columns:
    in_scope = in_scope.merge(
        citibike_detail[['venue_id', 'citibike_nearest_distance_m']],
        on='venue_id', how='left'
    )
else:
    in_scope['citibike_nearest_distance_m'] = None

# Calculate scores
scores = []
for _, row in in_scope.iterrows():
    score = vs.calculate_priority_score(
        venue_type=row['venue_type'],
        district=row['district'],
        review_count=vs.get_review_count(row['name']),
        rating=row.get('rating'),
        citibike_distance_m=row.get('citibike_nearest_distance_m'),
        district_label_coverage=district_label_coverage,
    )
    scores.append(score)

in_scope['priority_score'] = scores
in_scope = in_scope.sort_values('priority_score', ascending=False)

print(f'Priority scores calculated for {len(in_scope)} in-scope venues')
print(f'\nScore distribution:')
print(in_scope['priority_score'].describe().to_string())
print(f'\nTop 10 candidates:')
print(in_scope[['name', 'venue_type', 'district', 'priority_score']].head(10).to_string(index=False))
# Out:
# Priority scores calculated for 1559 in-scope venues
#
# Score distribution:
# count    1559.000000
# mean        6.684983
# std         0.807703
# min         3.497895
# 25%         6.166506
# 50%         6.900608
# 75%         7.354113
# max         7.705027
#
# Top 10 candidates:
#                                 name venue_type     district  priority_score
#           HSS Ambulatory Care Clinic healthcare midtown_east        7.705027
# Inwood Hill Park (Payson Playground)   restroom       uptown        7.703020
#     Weill Cornell Medical Associates healthcare midtown_east        7.702872
#           Alfred E. Smith Playground   restroom     downtown        7.702075
#                     Vein Care Center healthcare     downtown        7.691965
#   Laurance S Rockefeller OP Pavilion healthcare midtown_east        7.688866
#                   Allen Street Malls   restroom     downtown        7.676072
#        Queensboro Oval Indoor Tennis   restroom midtown_east        7.672834
#           Louis Brandeis High School healthcare midtown_east        7.664823
#         Chatham Square Library, NYPL   restroom     downtown        7.662672

# %% [markdown]
# ---
# ## SerpApi Batch Discovery
#
# **Strategy (SOP)**:
# - Use Search API with `category + district` queries to batch-discover venues with `popular_times`
# - Each search returns up to 20 results → costs 1 API call
# - Match results to local venues by proximity (haversine < 100m)
# - Do NOT call Place API per venue here
#
# **API Budget**: 250 calls/month total. This workflow uses ~16 Search + ~100 Place = ~116 calls.

# %%
# Cell 8: SerpApi batch discovery
search_results = []

if DRY_RUN:
    print('=== DRY-RUN MODE ===')
    print('No SERPAPI_API_KEY set. Generating synthetic results for pipeline testing.')
    print('To run live: export SERPAPI_API_KEY=your_key_here\n')
    
    # Generate synthetic search results for testing the pipeline
    # Simulate: each category×district search finds some venues with popular_times
    np.random.seed(42)
    for cat_query, google_type, clearpath_type in vs.SERPAPI_SEARCH_CATEGORIES:
        for district in vs.DISTRICT_CENTERS.keys():
            # Get venues of this type in this district
            mask = (in_scope['venue_type'] == clearpath_type) & (in_scope['district'] == district)
            district_venues = in_scope[mask]
            
            # Simulate: 20-40% of healthcare venues have popular_times
            sample_size = min(5, len(district_venues))
            if sample_size == 0:
                continue
            
            sampled = district_venues.sample(n=sample_size, random_state=42)
            
            for _, venue in sampled.iterrows():
                has_pt = np.random.random() < 0.30  # 30% have popular_times
                result = vs.SerpApiSearchResult(
                    place_id=f'ChIJ_{venue["venue_id"][:10]}',
                    data_id=f'0x{hash(venue["venue_id"]) % (10**16):016x}',
                    name=venue['name'],
                    address=venue.get('address', ''),
                    latitude=venue['latitude'],
                    longitude=venue['longitude'],
                    rating=venue.get('rating'),
                    reviews=vs.get_review_count(venue['name']),
                    type=google_type,
                    has_popular_times=has_pt,
                    popular_times_summary={'synthetic': True} if has_pt else None,
                    search_query=cat_query,
                    search_category=clearpath_type,
                    search_district=district,
                )
                search_results.append(result)
    
    print(f'Synthetic results generated: {len(search_results)}')
    print(f'With popular_times (simulated): {sum(1 for r in search_results if r.has_popular_times)}')

else:
    print('=== LIVE MODE ===')
    print(f'Using SerpApi key: ...{SERPAPI_KEY[-4:]}')
    search_results = vs.batch_search_discovery(
        venues=in_scope,
        api_key=SERPAPI_KEY,
        output_dir=OUTPUT_DIR,
        log_fn=print,
    )
# Out:
# === DRY-RUN MODE ===
# No SERPAPI_API_KEY set. Generating synthetic results for pipeline testing.
# To run live: export SERPAPI_API_KEY=your_key_here
#
# Synthetic results generated: 80
# With popular_times (simulated): 30

# %%
# Cell 8b: Cross-match SerpApi search results to local DB venues
matched_candidate_rows = []

for r in search_results:
    matched = vs._find_matching_venues(
        in_scope,
        r.latitude,
        r.longitude,
        max_distance_m=100,
    )

    for _, venue in matched.iterrows():
        if venue["venue_type"] != r.search_category:
            continue

        matched_candidate_rows.append({
            "venue_id": venue["venue_id"],
            "venue_name": venue["name"],
            "venue_type": venue["venue_type"],
            "district": venue["district"],
            "serpapi_place_id": r.place_id,
            "serpapi_name": r.name,
            "serpapi_type": r.type,
            "rating": r.rating,
            "reviews": r.reviews or 0,
            "distance_m": venue.get("_distance_m"),
            "result_obj": r,
        })

matched_candidates_df = pd.DataFrame(matched_candidate_rows)

if matched_candidates_df.empty:
    print("No SerpApi candidates matched local DB venues within 100m + same venue_type.")
else:
    matched_candidates_df = (
        matched_candidates_df
        .sort_values(["reviews", "rating"], ascending=[False, False])
        .drop_duplicates(subset=["venue_id"], keep="first")
        .reset_index(drop=True)
    )

    print(f"Matched DB venues: {len(matched_candidates_df)}")
    print(f"Unique venue_ids: {matched_candidates_df['venue_id'].nunique()}")
    print(f"Unique place_ids: {matched_candidates_df['serpapi_place_id'].nunique()}")
    print(matched_candidates_df[[
        "venue_id", "venue_name", "district", "serpapi_name",
        "serpapi_type", "reviews", "rating", "distance_m"
    ]].head(20).to_string(index=False))
# Out:
# Matched DB venues: 39
# Unique venue_ids: 39
# Unique place_ids: 20
#                             venue_id                                     venue_name     district                           serpapi_name serpapi_type  reviews  rating  distance_m
# 4ba8c5cf8a26f47bfeaea0e58902734d993c                            Equal Care Pharmacy     downtown                    Equal Care Pharmacy     hospital      437     NaN    0.000000
# 9805988b7c84df2925d61eebb312c5934717                                 MJHS Home Care     downtown              Metropolitan Jewish Lhcsa     hospital      422     NaN    0.000000
# 2e68ab82e27793d3e328a00e3c1d3231ecc5                      Metropolitan Jewish Lhcsa     downtown              Metropolitan Jewish Lhcsa     hospital      422     NaN    0.000000
# df8a76ebaa13977d74677134d8721c2cd58b                       HHC Health and Home Care     downtown              Metropolitan Jewish Lhcsa     hospital      422     NaN   66.013740
# 82297632b2a38eec7cc03f93234e914679ea         MJHS Hospice and Palliative Care, Inc.     downtown              Metropolitan Jewish Lhcsa     hospital      422     NaN    0.000000
# f169eb0dd90e0e636206118f5c005e140f9b                                   CVS Pharmacy midtown_west                           CVS Pharmacy     hospital      416     NaN    0.000000
# ea585f145c0af558b3ac3a6258e993fca8a2                            MedRite Urgent Care midtown_west                           CVS Pharmacy     hospital      416     NaN   96.489384
# 80031497127d9d76dc713da0f194f7cde0d8                                 Covenant House midtown_west                           CVS Pharmacy     hospital      416     NaN   84.417700
# 0f54de70894c1ae207a5a128ed54ae25a53d                                   CVS Pharmacy midtown_west                           CVS Pharmacy     hospital      416     NaN    0.000000
# 8a50d578d213cf7c47bb42bc9f77b8f9fb2c               Weill Cornell Medical Associates midtown_east                    Mount Sinai Doctors     hospital      405     NaN   94.399097
# bd8b7ace8f891981e83c4bab696f44b89165                            Mount Sinai Doctors midtown_east                    Mount Sinai Doctors     hospital      405     NaN    0.000000
# 6736f8aa2bda3055f0af644570868dd6820c                            MedRite Urgent Care midtown_east                    Mount Sinai Doctors     hospital      405     NaN   92.764475
# 0d15255ebd2da0a637df02278c56f27d7e69                           Health Wise Pharmacy midtown_east                   Health Wise Pharmacy     hospital      329     NaN    0.000000
# 72bb74be0f30bd52179ce4f2f0c2fd14d41a                                    Duane Reade midtown_east                   Health Wise Pharmacy     hospital      329     NaN   42.774780
# 67465cdb82f7ffad86d59681999bee743d50 Vitreous Retina Macula Consultants of New York     downtown Charles B Wang Comm Health Care Center     hospital      296     NaN   81.183608
# 9a3818fa7d851198c7e7092b34d89d45cf38         Charles B Wang Comm Health Care Center     downtown Charles B Wang Comm Health Care Center     hospital      296     NaN    0.000000
# f4ccb8522304efe11cbb7278f5d2a649971f                               CUHC Mobile Unit       uptown                   Mobile Dental Center     hospital      231     NaN    0.000000
# d6bc5474b004fe113ea349785d00c4b97d8f                           Mobile Dental Center       uptown                   Mobile Dental Center     hospital      231     NaN    0.000000
# c800d8ba099efd56b8b9b72f0ede798c211a                        Mobile Health Center #2       uptown                  Harlem East Life Plan     hospital      222     NaN   98.282387
# 3d59104d816b173a6da40b0a809e0d8ef779                          Harlem East Life Plan       uptown                  Harlem East Life Plan     hospital      222     NaN    0.000000

# %%
# Cell 9: Search results analysis
if search_results:
    results_df = pd.DataFrame([vars(r) for r in search_results])
    print(f'\nSearch Results Summary:')
    print(f'  Total discovered: {len(results_df)}')
    print(f'  With popular_times: {results_df["has_popular_times"].sum()}')
    print(f'  Without popular_times: {(~results_df["has_popular_times"]).sum()}')
    print(f'\nBy category:')
    print(results_df.groupby('search_category')['has_popular_times'].agg(['count', 'sum']).to_string())
    print(f'\nBy district:')
    print(results_df.groupby('search_district')['has_popular_times'].agg(['count', 'sum']).to_string())
else:
    print('No search results (check API key or try dry-run mode)')
# Out:
# Search Results Summary:
#   Total discovered: 80
#   With popular_times: 30
#   Without popular_times: 50
#
# By category:
#                  count  sum
# search_category
# healthcare          80   30
#
# By district:
#                  count  sum
# search_district
# downtown            20    8
# midtown_east        20    7
# midtown_west        20    7
# uptown              20    8

# %% [markdown]
# ---
# ## Place API Validation (Step 2: Verify)
#
# SerpApi Search 不返回 `popular_times`。必须用 Place API 逐个核实。
# 只验证已经和 DB venue 匹配上的候选，按 reviews + rating 排序取前 N 个。

# %%
# ⚠️ 消耗API, 谨慎操作! LIVE 模式下最多调用 100 次 Place API
MAX_PLACE_VALIDATION_CALLS = 100  # 每次最多调 100 次 Place API

if DRY_RUN:
    print('=== DRY-RUN: Skipping Place API validation ===')
    validated_results = search_results  # use search results as-is
else:
    if matched_candidates_df.empty:
        print('No matched candidates to validate.')
        validated_results = []
    else:
        candidates_to_validate = (
            matched_candidates_df['result_obj']
            .drop_duplicates()
            .head(MAX_PLACE_VALIDATION_CALLS)
            .tolist()
        )

        print(f'Validating {len(candidates_to_validate)} matched candidates via Place API...')
        print('Note: Search API popular_times=0 is not used as a filter.')

        validated_results = vs.validate_candidates_with_place_api(
            candidates=candidates_to_validate,
            api_key=SERPAPI_KEY,
            output_dir=OUTPUT_DIR,
            max_calls=MAX_PLACE_VALIDATION_CALLS,
            log_fn=print,
        )
# Out:
# === DRY-RUN: Skipping Place API validation ===

# %% [markdown]
# ---
# ## Label Status & ML Candidate List

# %%
# Cell 11: Generate label status for all venues
label_status_df = vs.generate_label_status(
    venues=venues,
    search_results=validated_results,
    citibike_detail=citibike_detail,
)

print(f'Label Status Summary:')
print(f'  Total venues: {len(label_status_df)}')
print(f'\n  By label_status:')
print(label_status_df['label_status'].value_counts().to_string())
print(f'\n  ML eligible: {label_status_df["ml_eligible"].sum()}')
print(f'  Not eligible: {(~label_status_df["ml_eligible"]).sum()}')
print(f'\n  By prediction_source:')
print(label_status_df['prediction_source'].value_counts().to_string())
# Out:
# Label Status Summary:
#   Total venues: 4838
#
#   By label_status:
# label_status
# api_not_checked      4799
# has_popular_times      35
# no_popular_times        4
#
#   ML eligible: 35
#   Not eligible: 4803
#
#   By prediction_source:
# prediction_source
# none             3279
# rule_fallback    1524
# ml_model           35

# %%
# Cell 12: Update category and district audits with label status
cat_audit_final = vs.audit_coverage_by_category(venues, label_status_df)
dist_audit_final = vs.audit_coverage_by_district(venues, label_status_df)

print('Category Coverage (with label status):')
print(cat_audit_final.to_string(index=False))
print(f'\nDistrict Coverage (with label status):')
print(dist_audit_final.to_string(index=False))
# Out:
# Category Coverage (with label status):
#       category  total_venues  out_of_scope  ml_eligible  no_data  has_popular_times  checked_count  ml_coverage_pct  validation_success_pct
# emergencyasset          3279          3279            0        0                  0              0              0.0                     NaN
#     healthcare          1086             0           35     1051                 35             39              3.2                    89.7
#       restroom           473             0            0      473                  0              0              0.0                     NaN
#
# District Coverage (with label status):
#     district  total_venues  out_of_scope  ml_eligible  no_data  has_popular_times  checked_count  ml_coverage_pct  validation_success_pct
#     downtown          1467           901           11      555                 11             11              1.9                   100.0
# midtown_east          1182           786            9      387                  9             11              2.3                    81.8
# midtown_west          1428          1211            7      210                  7              7              3.2                   100.0
#       uptown           703           381            8      314                  8             10              2.5                    80.0

# %%
# Cell 13: Generate ML candidate list
candidates_path = OUTPUT_DIR / 'venue_ml_candidates.csv'
candidates = vs.generate_candidate_list(label_status_df, candidates_path)
print(f'ML Candidates: {len(candidates)} venues')
print(f'Saved to: {candidates_path}')
if len(candidates) > 0:
    print(f'\nTop 10 ML candidates:')
    print(candidates[['venue_id', 'name', 'venue_type', 'district', 'serpapi_place_id']].head(10).to_string(index=False))
# Out:
# ML Candidates: 35 venues
# Saved to: /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/output/venue_ml_candidates.csv
#
# Top 10 ML candidates:
#                             venue_id                                    name venue_type     district serpapi_place_id
# 0463583968f2ae3ffc433493bb5838fb7690 PS 171 Patrick Henry Preparatory School healthcare midtown_east  ChIJ_0463583968
# 0d936bf077d1346b5d9691750270f91fc00b                             Tooth Works healthcare midtown_west  ChIJ_0d936bf077
# 0f54de70894c1ae207a5a128ed54ae25a53d                            CVS Pharmacy healthcare midtown_west  ChIJ_0f54de7089
# 1c9f9a57dd2e0bb3401e6e40c2e14d125ffd                             Duane Reade healthcare midtown_west  ChIJ_1c9f9a57dd
# 24639f2fdd26163a73ca37499e7334ed2642         Lafayette Medical Approach, LLC healthcare     downtown  ChIJ_24639f2fdd
# 291e57d749f1fc2fb65fa6609a189cda377a                       Cherry's Pharmacy healthcare midtown_east  ChIJ_bdaf2b343d
# 2e68ab82e27793d3e328a00e3c1d3231ecc5               Metropolitan Jewish Lhcsa healthcare     downtown  ChIJ_2e68ab82e2
# 35074031d5ac98633d514419ea407be116ec            8th Avenue Dental Associates healthcare     downtown  ChIJ_d97e415f4c
# 4ba8c5cf8a26f47bfeaea0e58902734d993c                     Equal Care Pharmacy healthcare     downtown  ChIJ_4ba8c5cf8a
# 6736f8aa2bda3055f0af644570868dd6820c                     MedRite Urgent Care healthcare midtown_east  ChIJ_bd8b7ace8f

# %%
# Cell 14: Save label status CSV
label_status_path = OUTPUT_DIR / 'venue_label_status.csv'
label_status_df.to_csv(label_status_path, index=False)
print(f'Label status saved to: {label_status_path}')
print(f'  Rows: {len(label_status_df)}')
print(f'  Columns: {list(label_status_df.columns)}')
# Out:
# Label status saved to: /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/output/venue_label_status.csv
#   Rows: 4838
#   Columns: ['venue_id', 'venue_type', 'district', 'name', 'latitude', 'longitude', 'label_status', 'ml_eligible', 'prediction_source', 'display_level', 'serpapi_checked_at', 'serpapi_place_id', 'priority_score', 'category_importance', 'review_count', 'rating', 'citibike_nearest_m', 'notes']

# %%
# Cell 15: Generate coverage audit report
report_path = OUTPUT_DIR / 'coverage_audit_report.md'
report = vs.generate_coverage_report(
    category_audit=cat_audit_final,
    district_audit=dist_audit_final,
    citibike_audit=cb_audit,
    label_status_df=label_status_df,
    search_results=search_results,
    output_path=report_path,
)
print(f'Report saved to: {report_path}')
print(f'\n--- Report Preview (first 50 lines) ---')
for line in report.split('\n')[:50]:
    print(line)
# Out:
# Report saved to: /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/output/coverage_audit_report.md
#
# --- Report Preview (first 50 lines) ---
# # Venue ML Coverage Audit Report
#
# > Generated: 2026-06-28 22:42 UTC
#
# ## Summary
#
# | Metric | Count | Pct |
# |--------|------:|----:|
# | Total venues | 4838 | 100% |
# | In-scope (healthcare + restroom) | 1559 | 32.2% |
# | Out-of-scope (AED) | 3279 | 67.8% |
# | Has popular_times | 35 | 2.2% of in-scope |
# | No popular_times | 4 | 0.3% of in-scope |
# | Not checked (API) | 1520 | 97.5% of in-scope |
# | **ML eligible** | **35** | **2.2% of in-scope** |
#
# ## SerpApi Usage
#
# - Search API calls: 16 category×district queries
# - Results discovered: 80
# - Results with popular_times: 30
#
# ## Category Coverage
#
# | category       |   total_venues |   out_of_scope |   ml_eligible |   no_data |   has_popular_times |   checked_count |   ml_coverage_pct |   validation_success_pct |
# |:---------------|---------------:|---------------:|--------------:|----------:|--------------------:|----------------:|------------------:|-------------------------:|
# | emergencyasset |           3279 |           3279 |             0 |         0 |                   0 |               0 |               0   |                    nan   |
# | healthcare     |           1086 |              0 |            35 |      1051 |                  35 |              39 |               3.2 |                     89.7 |
# | restroom       |            473 |              0 |             0 |       473 |                   0 |               0 |               0   |                    nan   |
#
# ## District Coverage
#
# | district     |   total_venues |   out_of_scope |   ml_eligible |   no_data |   has_popular_times |   checked_count |   ml_coverage_pct |   validation_success_pct |
# |:-------------|---------------:|---------------:|--------------:|----------:|--------------------:|----------------:|------------------:|-------------------------:|
# | downtown     |           1467 |            901 |            11 |       555 |                  11 |              11 |               1.9 |                    100   |
# | midtown_east |           1182 |            786 |             9 |       387 |                   9 |              11 |               2.3 |                     81.8 |
# | midtown_west |           1428 |           1211 |             7 |       210 |                   7 |               7 |               3.2 |                    100   |
# | uptown       |            703 |            381 |             8 |       314 |                   8 |              10 |               2.5 |                     80   |
#
# ## Citi Bike Proximity Distribution
#
# | proximity_bucket    |   total_venues |   in_scope_venues |   pct_of_total |
# |:--------------------|---------------:|------------------:|---------------:|
# | 0-100m              |           2199 |               645 |           45.5 |
# | 100-200m            |           2239 |               702 |           46.3 |
# | 200-300m            |            303 |               127 |            6.3 |
# | 300-500m            |             26 |                25 |            0.5 |
# | 500m+               |             13 |                 2 |            0.3 |
# | invalid_coordinates |             58 |                58 |            1.2 |

# %%
# Cell 16: Save run metadata
meta = vs.save_run_metadata(
    venues=venues,
    search_results=search_results,
    label_status_df=label_status_df,
    output_dir=OUTPUT_DIR,
    api_calls_search=0 if DRY_RUN else len(set(r.search_query + r.search_district for r in search_results)),
    api_calls_place=0 if DRY_RUN else len([r for r in search_results if r.has_popular_times]),
)
print(f'Run metadata saved to: {OUTPUT_DIR / "run_metadata.json"}')
print(json.dumps(meta, indent=2))
# Out:
# Run metadata saved to: /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/output/run_metadata.json
# {
#   "run_id": "20260628T224231Z",
#   "timestamp": "2026-06-28T22:42:31.359740+00:00",
#   "venue_input": {
#     "total_rows": 4838,
#     "venue_types": {
#       "emergencyasset": 3279,
#       "healthcare": 1086,
#       "restroom": 473
#     },
#     "districts": {
#       "downtown": 1467,
#       "midtown_west": 1428,
#       "midtown_east": 1182,
#       "uptown": 703
#     }
#   },
#   "serpapi_usage": {
#     "search_calls": 0,
#     "place_calls": 0,
#     "total_calls": 0,
#     "monthly_quota_remaining": 250
#   },
#   "results": {
#     "total_discovered": 80,
#     "with_popular_times": 30
#   },
#   "label_status": {
#     "api_not_checked": 4799,
#     "has_popular_times": 35,
#     "no_popular_times": 4
#   },
#   "out_of_scope_count": 3279,
#   "ml_eligible_count": 35
# }

# %%
# Cell 17: Final summary — all output artifacts
print('=' * 60)
print('VENUE ML COVERAGE WALKTHROUGH — COMPLETE')
print('=' * 60)
print(f'\nOutput directory: {OUTPUT_DIR}')
print(f'\nArtifacts generated:')
for f in sorted(OUTPUT_DIR.rglob('*')):
    if f.is_file():
        size = f.stat().st_size
        print(f'  {str(f.relative_to(OUTPUT_DIR)):<45} {size:>8,} bytes')

print(f'\nKey metrics:')
print(f'  Total venues:          {len(venues):,}')
print(f'  In-scope (SerpApi screening): {len(venues[~venues["venue_type"].isin(vs.OUT_OF_SCOPE_CATEGORIES)]):,}')
print(f'  Out-of-scope (AED):    {len(venues[venues["venue_type"].isin(vs.OUT_OF_SCOPE_CATEGORIES)]):,}')
print(f'  ML eligible:           {label_status_df["ml_eligible"].sum():,}')
print(f'  prediction_source=ml_model:  {(label_status_df["prediction_source"] == "ml_model").sum():,}')
print(f'  prediction_source=rule_fallback: {(label_status_df["prediction_source"] == "rule_fallback").sum():,}')
print(f'  prediction_source=none:      {(label_status_df["prediction_source"] == "none").sum():,}')
print(f'\nMode: {"DRY-RUN (synthetic data)" if DRY_RUN else "LIVE (real SerpApi data)"}')
print(f'Completed: {datetime.now():%Y-%m-%d %H:%M}')
# Out:
# ============================================================
# VENUE ML COVERAGE WALKTHROUGH — COMPLETE
# ============================================================
#
# Output directory: /Users/alex/Documents/COMP47360-Research_Practicum/Group6_Summer-Project/Data+ML/test/6.22-6.27/output
#
# Artifacts generated:
#   api_usage_20260628T222906Z.json                    292 bytes
#   api_usage_log.jsonl                             11,202 bytes
#   coverage_audit_report.md                         4,250 bytes
#   coverage_audit_report_zh.md                      3,313 bytes
#   healthcare_prediction_group_members.csv        233,537 bytes
#   healthcare_prediction_groups.csv               178,840 bytes
#   healthcare_uncovered_discovery_matches.csv      48,352 bytes
#   restroom_popular_times_audit.csv                35,929 bytes
#   run_metadata.json                                  735 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_026c8a5248ad.json   32,640 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_04204599666c.json   21,535 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_044dfbf2acdd.json   20,757 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_0951024344ef.json   21,486 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_0aff6b1528f3.json   26,571 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_0b88427695b6.json   21,617 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_0e72f12f80c4.json   22,793 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_0eb5444b7d14.json   24,812 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_0fc77670b1ab.json   37,063 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_13123fd9c900.json   46,741 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_14cfaf17afaa.json   23,185 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_14f104242854.json   23,390 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_150c9c78137b.json   15,910 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_157381e1ca7f.json   20,657 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_159ddf16a979.json   13,343 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1611662209d3.json   55,875 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1892f9285f1b.json   44,692 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_189cc231d99e.json   27,943 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1aefbe91c173.json   39,642 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1c11dd2143e5.json   50,020 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1ddd2d056954.json   11,531 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1e7aaa7ba745.json   18,962 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_1e97f56d1c75.json   20,308 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_219bac7a295a.json   21,024 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_22e63816025c.json   45,728 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_2309385bdba9.json   34,830 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_237e24692b79.json   12,136 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_25fec6bc9682.json   17,226 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_272448b9e36e.json   11,883 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_292feba0bcfa.json   41,447 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_2bea40b6c163.json   12,027 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_2c4b07c4c6f1.json   35,215 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_353fad71622a.json   20,865 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_36851b39b753.json   21,763 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_37b8fde91d96.json   30,642 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_387272485c48.json   15,098 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3a3a5cb8815e.json   22,140 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3b5852060afe.json   20,525 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3c339ca0c4d8.json   15,982 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3cb2d5f0df9c.json   48,265 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3d08c91a46a1.json   22,786 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3da31f987334.json   62,942 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_3ef811a140ea.json   24,845 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_4023299a1988.json   38,107 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_40427d1f6592.json   57,298 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_42974a91c0db.json   21,400 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_44c0d5baacf8.json   40,646 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_46bd828040a5.json   33,648 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_47e524bc0ec3.json   22,268 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_4a18c8cf0be8.json   39,587 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_4a1b7a4caea4.json   20,167 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_4bc6feea8be3.json   15,184 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_4bd622f3e6fc.json   21,075 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_502239a2a0c0.json   33,619 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_546bcfc61b3d.json   48,328 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_558afe1b982c.json   47,494 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_55a00c374548.json   20,113 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_56308a74efdf.json   34,648 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_56c0629ec230.json   23,280 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_574ec2a8de32.json   24,064 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_5aca033b39d2.json   27,450 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_5cc15bdad841.json   27,489 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_5ead6162be45.json   10,118 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_634444f4b5bc.json   19,777 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_63b61a40f884.json   24,064 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_64899f2f0348.json   21,446 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_64d2f6ba8ed4.json   36,177 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_672975494554.json   23,517 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_69a817f5823b.json   38,965 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_69d80766ddb6.json   10,492 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_6bfed4f96742.json   23,850 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_6fcd300b95df.json   35,939 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_718599c7d6db.json   21,544 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_75ffcfb168b2.json   22,126 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_76935190b0d3.json   40,155 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_79d24fc098db.json   12,448 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_7a0aa8667188.json   20,391 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_7bab0634b4c4.json   18,412 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_7c0e3381d7f7.json   26,621 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_80fc4262c48c.json   23,435 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8521fc82804d.json   21,169 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_88e271eca036.json   32,094 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8a7aec15c89b.json   38,047 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8c5c720af710.json   37,350 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8ceb2bf166dd.json   22,199 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8db11bbe72b0.json   34,126 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8e06b74fbf59.json   20,935 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_8e3c307069d5.json   23,350 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_918b15c7136f.json   37,418 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_921f3e6f1bd4.json   46,396 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_92c43a5d75a5.json   21,940 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_955b6ad332dd.json   33,243 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_97d1a333bda1.json   36,912 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_9947574a47d4.json   34,371 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_9a2ce5fbdac5.json   35,382 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_9ad14a4e20b4.json   44,555 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_9ad4cea2c412.json   20,980 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_9aea6ed43647.json   46,269 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_9bb02d7371a5.json   25,491 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a0271740ae65.json   18,781 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a1c6b0520ff4.json   23,356 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a2203a2ddf17.json   40,777 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a220c3aaa492.json   47,781 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a23be66a484f.json   17,735 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a5019db06fa3.json    8,797 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_a6f678d0f097.json   43,902 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_aa1d3788b60f.json   40,349 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_aa9b76e0a94e.json   21,562 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_ab21819d1360.json   60,800 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b024359a0b8c.json   36,817 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b28bacfac85a.json   53,602 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b2c6005f6dd5.json   24,707 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b37db6effe42.json   20,092 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b5620377e25f.json   46,513 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b6890aff4fa8.json   24,010 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b717d92d82ce.json   17,470 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b862f22f9553.json   19,709 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_b8ae3b6f0ab1.json   36,616 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_be5f337d6d0b.json   10,500 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_bea361b63ba1.json   36,521 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_bf6f9af9609f.json   23,788 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_c42b74baadf8.json   29,084 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_c64302c3c954.json   19,538 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_c6c8e6d507f8.json   20,307 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_c748ff5d4e7b.json   24,029 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_cbb245e8b09d.json   38,053 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_cdde07b2cca0.json   40,996 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_cf026bb9cb68.json   18,320 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_cf7b214b56a7.json   18,694 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_cf9af5bd3527.json   25,729 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_cfbcadc275e2.json   39,242 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d2ba03b96b8e.json   31,830 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d4237613351a.json   10,728 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d42913a53776.json   51,416 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d48d97a47131.json   21,689 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d6ca63761b67.json   14,186 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d8f46489f832.json   10,007 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_d9c86f774751.json   33,720 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_da89a6e48928.json   38,339 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_db025c5f788e.json    9,488 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_dc311d77f8f6.json   15,846 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_de0e09878c34.json   44,120 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_de68226481e2.json   13,764 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_def13da16e3a.json   48,488 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_e1015a60422f.json   20,716 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_e1e3dda7e241.json   26,227 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_e5d4d0a3cffb.json   22,165 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_e8aa8b638866.json   26,623 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_e96761d0f008.json   44,091 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_ea95b212bf9a.json   54,068 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_ee4ed18cd204.json   24,703 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_ee67df0f0507.json   41,611 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_ef085edf0f2c.json   25,438 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_eff5d13607a9.json   38,388 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_f57a1ab7cbea.json   17,719 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_f6bf92cc2074.json   25,315 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_f9e0ff2ef7e8.json    6,847 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_fc2b5c8c8312.json   37,204 bytes
#   serpapi_raw_responses/healthcare_search_matched_place_fcf3252dda01.json   30,123 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_24959b75882d.json    9,993 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_3a94bb1672fc.json   20,835 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_41a8742a9370.json   17,474 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_6e8ac823f8c2.json   23,157 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_ae61edab60bf.json   35,331 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_ae64159bfe70.json   43,229 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_c2a21cc8694d.json   33,192 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_dd02101d488c.json   13,642 bytes
#   serpapi_raw_responses/healthcare_uncovered_place_f9a221942d5f.json   14,924 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_067afbfcfebd.json   12,044 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_0ea86a7fc936.json   25,470 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_0ecafbc04f0c.json   72,992 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_1092f72f6286.json    6,914 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_14f3c2642481.json   21,469 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_297fe450aeec.json   31,062 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_2abe1bcfd214.json   47,856 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_4bcc98ddf932.json    9,847 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_724668670860.json   43,744 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_764ddb9edb4a.json   12,381 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_7e9ef1966d37.json    5,532 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_94816d77392e.json   63,195 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_9baded07daea.json   30,386 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_9d76345f8656.json    5,771 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_a601d2d4610f.json   40,084 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_c97e7fdf6f5c.json   65,738 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_e1817d7d4b73.json   23,752 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_ebceb4d21a23.json   65,366 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_ef4d24096d55.json   30,164 bytes
#   serpapi_raw_responses/healthcare_uncovered_search_f10af2c25a55.json   25,823 bytes
#   serpapi_raw_responses/place_00750ecd6577.json   20,713 bytes
#   serpapi_raw_responses/place_0112f79ad0af.json   25,224 bytes
#   serpapi_raw_responses/place_06e86098d1b5.json   39,707 bytes
#   serpapi_raw_responses/place_0c99d29def91.json   39,256 bytes
#   serpapi_raw_responses/place_0db048046ab7.json   37,394 bytes
#   serpapi_raw_responses/place_0e0bb37a3bb0.json   23,999 bytes
#   serpapi_raw_responses/place_1261a2440f9e.json   39,618 bytes
#   serpapi_raw_responses/place_13957b1d830f.json   36,168 bytes
#   serpapi_raw_responses/place_13b8d229daff.json   60,818 bytes
#   serpapi_raw_responses/place_14532321297d.json   37,667 bytes
#   serpapi_raw_responses/place_14e961b7747d.json   37,150 bytes
#   serpapi_raw_responses/place_1518de610b35.json   21,301 bytes
#   serpapi_raw_responses/place_1723fcd69461.json   24,775 bytes
#   serpapi_raw_responses/place_18be0ef7fb07.json   36,579 bytes
#   serpapi_raw_responses/place_1a1dcf05d224.json   42,089 bytes
#   serpapi_raw_responses/place_1cfed73fe919.json   40,147 bytes
#   serpapi_raw_responses/place_1eda6e196d88.json   21,916 bytes
#   serpapi_raw_responses/place_2226d8b686ac.json   35,929 bytes
#   serpapi_raw_responses/place_246b89ce90f6.json  155,173 bytes
#   serpapi_raw_responses/place_285e1fea379f.json   24,222 bytes
#   serpapi_raw_responses/place_2ade87d47bd9.json   40,217 bytes
#   serpapi_raw_responses/place_2dfb116ecdd0.json   39,957 bytes
#   serpapi_raw_responses/place_3a5803584eb6.json   33,387 bytes
#   serpapi_raw_responses/place_3cb2d5f0df9c.json   48,386 bytes
#   serpapi_raw_responses/place_3e5fee7ca80a.json   69,456 bytes
#   serpapi_raw_responses/place_427d5d71ff77.json   52,157 bytes
#   serpapi_raw_responses/place_453f81a2d5ec.json   45,530 bytes
#   serpapi_raw_responses/place_46e0b1b96a85.json   21,781 bytes
#   serpapi_raw_responses/place_4773b7c7d07e.json   37,520 bytes
#   serpapi_raw_responses/place_4af652f82cb7.json   40,991 bytes
#   serpapi_raw_responses/place_4bb29fc0d505.json   35,183 bytes
#   serpapi_raw_responses/place_4eae92a5dc9b.json   41,280 bytes
#   serpapi_raw_responses/place_4fb821caff89.json   24,958 bytes
#   serpapi_raw_responses/place_509612c22108.json   28,561 bytes
#   serpapi_raw_responses/place_564642243d0e.json   30,787 bytes
#   serpapi_raw_responses/place_56c0629ec230.json   23,287 bytes
#   serpapi_raw_responses/place_5f9add93da3d.json   22,169 bytes
#   serpapi_raw_responses/place_6119a109c43f.json   25,072 bytes
#   serpapi_raw_responses/place_64543d013b09.json   47,824 bytes
#   serpapi_raw_responses/place_66777f7edf4c.json   33,928 bytes
#   serpapi_raw_responses/place_6ab96734b611.json   37,166 bytes
#   serpapi_raw_responses/place_6cdc340292a4.json   21,710 bytes
#   serpapi_raw_responses/place_6d1c6278bdf3.json   26,004 bytes
#   serpapi_raw_responses/place_6f530bf7d44b.json   24,416 bytes
#   serpapi_raw_responses/place_7322ebd8c502.json   30,681 bytes
#   serpapi_raw_responses/place_746fc29cb852.json   39,625 bytes
#   serpapi_raw_responses/place_79ef32d40999.json   24,549 bytes
#   serpapi_raw_responses/place_7b36ca274f15.json   34,063 bytes
#   serpapi_raw_responses/place_7c215b5f5acb.json   25,802 bytes
#   serpapi_raw_responses/place_7f632f180bf8.json   48,017 bytes
#   serpapi_raw_responses/place_80fc4262c48c.json   22,871 bytes
#   serpapi_raw_responses/place_838ca88af024.json   48,075 bytes
#   serpapi_raw_responses/place_85cfb31d92d3.json   33,968 bytes
#   serpapi_raw_responses/place_8984729f20c1.json   39,447 bytes
#   serpapi_raw_responses/place_8d31bca798e2.json   25,484 bytes
#   serpapi_raw_responses/place_8e0664986f31.json   25,388 bytes
#   serpapi_raw_responses/place_8ef07c4a5c1e.json   21,586 bytes
#   serpapi_raw_responses/place_93dcaf038dcd.json   23,765 bytes
#   serpapi_raw_responses/place_94a465d1f73c.json   37,267 bytes
#   serpapi_raw_responses/place_99638d75bb04.json   22,314 bytes
#   serpapi_raw_responses/place_9aea6ed43647.json   46,272 bytes
#   serpapi_raw_responses/place_9d1dcb746edc.json   55,957 bytes
#   serpapi_raw_responses/place_9e9f681c7839.json   34,332 bytes
#   serpapi_raw_responses/place_9ed2625608c4.json   18,458 bytes
#   serpapi_raw_responses/place_a0032e6addf7.json   24,421 bytes
#   serpapi_raw_responses/place_a04daa6f6008.json   22,893 bytes
#   serpapi_raw_responses/place_a220c3aaa492.json   47,782 bytes
#   serpapi_raw_responses/place_a6aa86cc7ad7.json   38,044 bytes
#   serpapi_raw_responses/place_aba0fb0ca848.json   37,495 bytes
#   serpapi_raw_responses/place_acfc69a55fe8.json   20,153 bytes
#   serpapi_raw_responses/place_b0887fef6fc2.json   23,216 bytes
#   serpapi_raw_responses/place_b2a56cc01376.json   22,849 bytes
#   serpapi_raw_responses/place_b2b3ca9b53a1.json   37,550 bytes
#   serpapi_raw_responses/place_ba17ea4a3b28.json   27,384 bytes
#   serpapi_raw_responses/place_bf9366cd8ab5.json   50,164 bytes
#   serpapi_raw_responses/place_c32911765fbb.json   21,218 bytes
#   serpapi_raw_responses/place_cbc08ee41d79.json  151,765 bytes
#   serpapi_raw_responses/place_ce3aed22a896.json   55,130 bytes
#   serpapi_raw_responses/place_d2ba03b96b8e.json   31,829 bytes
#   serpapi_raw_responses/place_d5b69ea1fec5.json   43,187 bytes
#   serpapi_raw_responses/place_d958a79be031.json   44,494 bytes
#   serpapi_raw_responses/place_db17d9f64c50.json   22,409 bytes
#   serpapi_raw_responses/place_e28047ac5f8d.json   34,246 bytes
#   serpapi_raw_responses/place_e508ea3ad94c.json   35,262 bytes
#   serpapi_raw_responses/place_e5d4d0a3cffb.json   22,176 bytes
#   serpapi_raw_responses/place_e8bb16fbc3f3.json   55,013 bytes
#   serpapi_raw_responses/place_e94d8e26aabd.json   21,792 bytes
#   serpapi_raw_responses/place_eae5ad229c10.json   39,156 bytes
#   serpapi_raw_responses/place_ec207c4e7481.json   23,669 bytes
#   serpapi_raw_responses/place_ee4ed18cd204.json   24,713 bytes
#   serpapi_raw_responses/place_eedf6beb87c9.json   24,056 bytes
#   serpapi_raw_responses/place_ef5b48732dbd.json   24,193 bytes
#   serpapi_raw_responses/place_f08bdfc93b48.json   65,822 bytes
#   serpapi_raw_responses/place_f161b3e68058.json   33,910 bytes
#   serpapi_raw_responses/place_f44c507dfd18.json   23,061 bytes
#   serpapi_raw_responses/place_f5567b42fa8b.json   32,726 bytes
#   serpapi_raw_responses/place_f6bf92cc2074.json   25,330 bytes
#   serpapi_raw_responses/place_f9a4318ea4dd.json   24,617 bytes
#   serpapi_raw_responses/place_fa57f7bca142.json   24,531 bytes
#   serpapi_raw_responses/place_fe3813ad3e54.json   40,665 bytes
#   serpapi_raw_responses/restroom_place_08a262f9ad47.json   37,386 bytes
#   serpapi_raw_responses/restroom_place_0b91b56b3f55.json   16,104 bytes
#   serpapi_raw_responses/restroom_place_239d3d2c34fa.json   31,777 bytes
#   serpapi_raw_responses/restroom_place_23b54c64d214.json   18,287 bytes
#   serpapi_raw_responses/restroom_place_3d87b470fbd0.json   36,448 bytes
#   serpapi_raw_responses/restroom_place_530775830233.json   34,556 bytes
#   serpapi_raw_responses/restroom_place_5e04c30d7828.json   21,597 bytes
#   serpapi_raw_responses/restroom_place_5f125a285859.json   18,593 bytes
#   serpapi_raw_responses/restroom_place_7d56264ee28a.json   20,956 bytes
#   serpapi_raw_responses/restroom_place_8e9c3ac868bc.json   18,155 bytes
#   serpapi_raw_responses/restroom_place_a53405798e83.json   17,220 bytes
#   serpapi_raw_responses/restroom_place_a6e26b7cdd59.json   20,544 bytes
#   serpapi_raw_responses/restroom_place_ab4a7b37daed.json   20,408 bytes
#   serpapi_raw_responses/restroom_place_b6850e130236.json   18,029 bytes
#   serpapi_raw_responses/restroom_place_b8627331c38a.json   48,162 bytes
#   serpapi_raw_responses/restroom_place_bfc36fad0466.json   19,703 bytes
#   serpapi_raw_responses/restroom_place_c2e2d217020f.json   19,803 bytes
#   serpapi_raw_responses/restroom_place_c45b99a21540.json   19,076 bytes
#   serpapi_raw_responses/restroom_place_c4665d9d577a.json   34,774 bytes
#   serpapi_raw_responses/restroom_place_cbe254cef874.json   22,397 bytes
#   serpapi_raw_responses/restroom_place_d23db4b5139e.json   17,520 bytes
#   serpapi_raw_responses/restroom_place_f309bf0e1e08.json   38,798 bytes
#   serpapi_raw_responses/restroom_place_f315b672f80f.json   23,624 bytes
#   serpapi_raw_responses/restroom_place_f8e21751e1a5.json   17,056 bytes
#   serpapi_raw_responses/restroom_place_fa7d07d6f7f2.json   19,107 bytes
#   serpapi_raw_responses/restroom_search_03a066a25c84.json   49,463 bytes
#   serpapi_raw_responses/restroom_search_1cf0b48abe52.json   44,139 bytes
#   serpapi_raw_responses/restroom_search_1cfa0fadbaf8.json   50,213 bytes
#   serpapi_raw_responses/restroom_search_28086fd24216.json   49,933 bytes
#   serpapi_raw_responses/restroom_search_37d2dde3ee2a.json   46,843 bytes
#   serpapi_raw_responses/restroom_search_3e866a0d6a14.json   48,622 bytes
#   serpapi_raw_responses/restroom_search_4caad2729ebd.json   47,104 bytes
#   serpapi_raw_responses/restroom_search_5f43f7d9da1d.json   48,829 bytes
#   serpapi_raw_responses/restroom_search_73ae5ed0ea8a.json   47,462 bytes
#   serpapi_raw_responses/restroom_search_78d0266aed3e.json   43,240 bytes
#   serpapi_raw_responses/restroom_search_823de33756d4.json   48,302 bytes
#   serpapi_raw_responses/restroom_search_8ca8ccadb52b.json   47,009 bytes
#   serpapi_raw_responses/restroom_search_9114bac00b72.json   48,550 bytes
#   serpapi_raw_responses/restroom_search_b55c7c8131a2.json   47,263 bytes
#   serpapi_raw_responses/restroom_search_ee48102c58ac.json   50,531 bytes
#   serpapi_raw_responses/restroom_search_ef88e68056c8.json   50,101 bytes
#   serpapi_raw_responses/search_01e6b7a2cef8.json   61,394 bytes
#   serpapi_raw_responses/search_034972bf3bda.json   55,309 bytes
#   serpapi_raw_responses/search_0774361a1a9c.json   63,586 bytes
#   serpapi_raw_responses/search_102733326a60.json   71,398 bytes
#   serpapi_raw_responses/search_13310ccf06b4.json   64,334 bytes
#   serpapi_raw_responses/search_141a4362407c.json   68,757 bytes
#   serpapi_raw_responses/search_158343e3fb49.json   72,498 bytes
#   serpapi_raw_responses/search_18866d5f48d1.json   62,030 bytes
#   serpapi_raw_responses/search_1bbc77272491.json   66,895 bytes
#   serpapi_raw_responses/search_1fd7a8fefcfe.json   67,199 bytes
#   serpapi_raw_responses/search_24bb5cb5eddb.json   69,426 bytes
#   serpapi_raw_responses/search_2631fdc5e5d8.json   59,850 bytes
#   serpapi_raw_responses/search_26a201216ce2.json   60,737 bytes
#   serpapi_raw_responses/search_26aa110f5c7b.json   75,357 bytes
#   serpapi_raw_responses/search_27c3879dfcc4.json   80,220 bytes
#   serpapi_raw_responses/search_2e82c97fc325.json   67,353 bytes
#   serpapi_raw_responses/search_327c6e2c5f6c.json   64,356 bytes
#   serpapi_raw_responses/search_35dc805f645a.json   68,401 bytes
#   serpapi_raw_responses/search_3a8a4c145fa5.json    1,108 bytes
#   serpapi_raw_responses/search_3b6c85496586.json   69,918 bytes
#   serpapi_raw_responses/search_3da261b50c73.json   73,134 bytes
#   serpapi_raw_responses/search_4369566315eb.json   53,240 bytes
#   serpapi_raw_responses/search_4ea7c22cf0e8.json   62,464 bytes
#   serpapi_raw_responses/search_57421f3cc67b.json   58,449 bytes
#   serpapi_raw_responses/search_5746de2e28ba.json   71,029 bytes
#   serpapi_raw_responses/search_5aa2c3dfd556.json   83,537 bytes
#   serpapi_raw_responses/search_61b31b04c60b.json   65,508 bytes
#   serpapi_raw_responses/search_64b42a6e2eb5.json   54,861 bytes
#   serpapi_raw_responses/search_679b950c39b4.json   73,541 bytes
#   serpapi_raw_responses/search_6a648ff5e267.json   67,352 bytes
#   serpapi_raw_responses/search_6c6d8d836cdc.json   84,996 bytes
#   serpapi_raw_responses/search_758ce868b16b.json   55,887 bytes
#   serpapi_raw_responses/search_83a23f499f9b.json    1,108 bytes
#   serpapi_raw_responses/search_862fdb00754b.json   72,900 bytes
#   serpapi_raw_responses/search_86ac8a57c5a1.json   57,364 bytes
#   serpapi_raw_responses/search_894de597b42f.json   55,399 bytes
#   serpapi_raw_responses/search_89dcd3b66c53.json   72,844 bytes
#   serpapi_raw_responses/search_8c44093c0f8f.json   52,543 bytes
#   serpapi_raw_responses/search_95a524e8c972.json   62,089 bytes
#   serpapi_raw_responses/search_9a1c3250ff15.json   56,967 bytes
#   serpapi_raw_responses/search_a14b551a24dd.json   69,463 bytes
#   serpapi_raw_responses/search_a3e92c7dc77b.json   70,558 bytes
#   serpapi_raw_responses/search_a651b321030b.json   70,588 bytes
#   serpapi_raw_responses/search_a8336e5de84f.json   69,645 bytes
#   serpapi_raw_responses/search_bb8cfe0c11fe.json   55,448 bytes
#   serpapi_raw_responses/search_bcaec2a4b4de.json   68,814 bytes
#   serpapi_raw_responses/search_be0758b09df7.json   67,655 bytes
#   serpapi_raw_responses/search_c00c63af534d.json   66,048 bytes
#   serpapi_raw_responses/search_c599b0c3f055.json   70,025 bytes
#   serpapi_raw_responses/search_c6347e98ec0e.json   70,743 bytes
#   serpapi_raw_responses/search_c6fe70a1ee54.json   74,730 bytes
#   serpapi_raw_responses/search_c9e50f298fe5.json   74,508 bytes
#   serpapi_raw_responses/search_ca3812929c6f.json   75,942 bytes
#   serpapi_raw_responses/search_cdaa14e13dbf.json   73,628 bytes
#   serpapi_raw_responses/search_d4fa4e39e580.json   76,585 bytes
#   serpapi_raw_responses/search_d952b80dbd86.json   64,113 bytes
#   serpapi_raw_responses/search_dbcaac8d4c3e.json   70,127 bytes
#   serpapi_raw_responses/search_dfbd9967b2d5.json   74,393 bytes
#   serpapi_raw_responses/search_e379f7384ed6.json   72,316 bytes
#   serpapi_raw_responses/search_e7988454241f.json   72,218 bytes
#   serpapi_raw_responses/search_eb1b79281f39.json   70,219 bytes
#   serpapi_raw_responses/search_ecc859fe6b2e.json   71,517 bytes
#   serpapi_raw_responses/search_f67fdc521321.json   40,071 bytes
#   serpapi_raw_responses/search_f796ded5755d.json   68,137 bytes
#   serpapi_raw_responses/search_fbe8f84e5f4f.json   59,853 bytes
#   serpapi_raw_responses/search_fce4f9bdeb91.json   68,161 bytes
#   venue_label_status.csv                        1,085,205 bytes
#   venue_label_status_coverage_view.csv          1,130,545 bytes
#   venue_label_status_grouped_view.csv           1,248,754 bytes
#   venue_ml_candidates.csv                          7,339 bytes
#
# Key metrics:
#   Total venues:          4,838
#   In-scope (SerpApi screening): 1,559
#   Out-of-scope (AED):    3,279
#   ML eligible:           35
#   prediction_source=ml_model:  35
#   prediction_source=rule_fallback: 1,524
#   prediction_source=none:      3,279
#
# Mode: DRY-RUN (synthetic data)
# Completed: 2026-06-28 23:45
