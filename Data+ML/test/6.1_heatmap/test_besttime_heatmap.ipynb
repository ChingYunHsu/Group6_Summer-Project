# %% [markdown]
# # BestTime Manhattan Demo
#
# This notebook shows the minimal BestTime workflow for a Manhattan venue. It creates one venue forecast, queries a Manhattan heatmap slice, and prints a compact summary that can be used for validation.
#
# The API key is written directly into the request payload for local smoke testing only. Replace the demo string with a real private key before running against the live API.

# %%
import json
from urllib.parse import urlencode
from urllib.error import HTTPError
from urllib.request import Request, urlopen

# BestTime endpoints used by the minimal demo.
BESTTIME_FORECAST_URL = "https://besttime.app/api/v1/forecasts"
BESTTIME_FILTER_URL = "https://besttime.app/api/v1/venues/filter"
BESTTIME_QUERY_WEEK_URL = "https://besttime.app/api/v1/forecasts/week"
BESTTIME_QUERY_WEEK_RAW_URL = "https://besttime.app/api/v1/forecasts/week/raw"
BESTTIME_QUERY_DAY_URL = "https://besttime.app/api/v1/forecasts/day"

# Demo-only plaintext API keys. Replace these locally before running live requests.
API_KEY_PUBLIC = "pub_2a23ebb7425f4a7bb33d5f218832140b"
API_KEY_PRIVATE = "pri_06e221c65c594b168de3ffd8d566a316"

# Manhattan reference point: Mount Sinai Hospital.
VENUE_NAME = "Grand Central Terminal"
VENUE_ADDRESS = "89 E 42nd St, New York, NY 10017"
LAT = 40.7527
LNG = -73.9772
RADIUS = 2500
MANHATTAN_LAT_MIN = 40.700
MANHATTAN_LAT_MAX = 40.882
MANHATTAN_LNG_MIN = -74.030
MANHATTAN_LNG_MAX = -73.910
DAY_INT = 2
HOUR_MIN = 8
HOUR_MAX = 18
# TYPES = "HOSPITAL,PHARMACY,DOCTOR"
TYPES = ""

# Query endpoints use an existing forecasted venue_id and the public API key.
QUERY_VENUE_ID = "ven_596330495256544749304e526b6f775a646234776365754a496843"

# Keep this false while forecast/Radar quota is exhausted. Query cells below do not use venue filter.
RUN_LIVE_HEATMAP = False

def post_query_json(url: str, params: dict) -> dict:
    # BestTime's official examples place POST parameters on the URL query string, not in the request body.
    query = urlencode(params)
    request = Request(f"{url}?{query}", method="POST")
    try:
        with urlopen(request, timeout=30) as response:
            return json.loads(response.read().decode("utf-8"))
    except HTTPError as exc:
        error_body = exc.read().decode("utf-8", errors="replace")
        raise RuntimeError(f"BestTime HTTP {exc.code}: {error_body}") from exc

def get_json(url: str, params: dict) -> dict:
    # This is the same pattern as the POST helper, but for a GET request with a query string.
    query = urlencode(params)
    request = Request(f"{url}?{query}", method="GET")
    try:
        with urlopen(request, timeout=30) as response:
            return json.loads(response.read().decode("utf-8"))
    except HTTPError as exc:
        error_body = exc.read().decode("utf-8", errors="replace")
        raise RuntimeError(f"BestTime HTTP {exc.code}: {error_body}") from exc

def create_forecast(api_key_private: str, venue_name: str, venue_address: str) -> dict:
    # Creates or refreshes a forecast for one concrete venue in Manhattan.
    return post_query_json(
        BESTTIME_FORECAST_URL,
        {
            "api_key_private": api_key_private,
            "venue_name": venue_name,
            "venue_address": venue_address,
        },
    )

def filter_manhattan(api_key_private: str, day_int: int, hour_min: int, hour_max: int, types: str = "") -> dict:
    # Uses a bounding box so one request can cover the entire Manhattan island.
    return get_json(
        BESTTIME_FILTER_URL,
        {
            "api_key_private": api_key_private,
            "lat_min": MANHATTAN_LAT_MIN,
            "lat_max": MANHATTAN_LAT_MAX,
            "lng_min": MANHATTAN_LNG_MIN,
            "lng_max": MANHATTAN_LNG_MAX,
            "day_int": day_int,
            "hour_min": hour_min,
            "hour_max": hour_max,
            "types": types,
            "foot_traffic": "both",
            "own_venues_only": False,
            "limit": 500,
            "page": 0,
        },
    )

def fetch_manhattan_pages(api_key_private: str, day_int: int, hour_min: int, hour_max: int, types: str = "", limit: int = 500, max_pages: int = 10) -> dict:
    # Fetch all matching venues page by page so we stay below the 500-venue per response ceiling.
    all_venues = []
    first_payload = None

    for page in range(max_pages):
        payload = get_json(
            BESTTIME_FILTER_URL,
            {
                "api_key_private": api_key_private,
                "lat_min": MANHATTAN_LAT_MIN,
                "lat_max": MANHATTAN_LAT_MAX,
                "lng_min": MANHATTAN_LNG_MIN,
                "lng_max": MANHATTAN_LNG_MAX,
                "day_int": day_int,
                "hour_min": hour_min,
                "hour_max": hour_max,
                "types": types,
                "foot_traffic": "both",
                "own_venues_only": False,
                "limit": limit,
                "page": page,
            },
        )
        if first_payload is None:
            first_payload = payload
        venues = payload.get("venues", [])
        all_venues.extend(venues)
        if len(venues) < limit:
            break

    if first_payload is None:
        return {"status": "Error", "venues": []}

    merged = dict(first_payload)
    merged["venues"] = all_venues
    merged["venues_n"] = len(all_venues)
    return merged


def query_week(api_key_public: str, venue_id: str) -> dict:
    # Query an existing forecast by venue_id. This avoids creating a new forecast.
    return get_json(
        BESTTIME_QUERY_WEEK_URL,
        {
            "api_key_public": api_key_public,
            "venue_id": venue_id,
        },
    )

def query_week_raw(api_key_public: str, venue_id: str) -> dict:
    # Query raw 0-100 weekly busyness values for an existing forecast.
    return get_json(
        BESTTIME_QUERY_WEEK_RAW_URL,
        {
            "api_key_public": api_key_public,
            "venue_id": venue_id,
        },
    )

def query_day(api_key_public: str, venue_id: str, day_int: int) -> dict:
    # Query one weekday for an existing forecast.
    return get_json(
        BESTTIME_QUERY_DAY_URL,
        {
            "api_key_public": api_key_public,
            "venue_id": venue_id,
            "day_int": day_int,
        },
    )

def summarize_heatmap(payload: dict) -> list:
    # Normalize the venue list into a compact table for inspection.
    venues = payload.get("venues", [])
    summary = []
    for venue in venues:
        day_raw = venue.get("day_raw_whole") or venue.get("day_raw") or []
        peak = max(day_raw) if day_raw else None
        summary.append({
            "venue_id": venue.get("venue_id"),
            "venue_name": venue.get("venue_name"),
            "lat": venue.get("venue_lat"),
            "lng": venue.get("venue_lng"),
            "peak_busyness": peak,
        })
    return summary

# %%
# This cell is disabled by default because venue filter/Radar can consume quota quickly.
if RUN_LIVE_HEATMAP:
    heatmap = fetch_manhattan_pages(API_KEY_PRIVATE, DAY_INT, HOUR_MIN, HOUR_MAX, TYPES, limit=500, max_pages=10)
else:
    heatmap = {"status": "disabled", "venues": [], "venues_n": 0, "bounding_box": None}

result = {
    "region": "Manhattan",
    "mode": "live_heatmap" if RUN_LIVE_HEATMAP else "disabled_to_save_quota",
    "query": {
        "lat_min": MANHATTAN_LAT_MIN,
        "lat_max": MANHATTAN_LAT_MAX,
        "lng_min": MANHATTAN_LNG_MIN,
        "lng_max": MANHATTAN_LNG_MAX,
        "day_int": DAY_INT,
        "hour_min": HOUR_MIN,
        "hour_max": HOUR_MAX,
        "types": TYPES,
    },
    "heatmap": {
        "venues_n": heatmap.get("venues_n"),
        "status": heatmap.get("status"),
        "bounding_box": heatmap.get("bounding_box"),
        "top_matches": summarize_heatmap(heatmap)[:10],
    },
}

print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# {
#   "region": "Manhattan",
#   "mode": "disabled_to_save_quota",
#   "query": {
#     "lat_min": 40.7,
#     "lat_max": 40.882,
#     "lng_min": -74.03,
#     "lng_max": -73.91,
#     "day_int": 2,
#     "hour_min": 8,
#     "hour_max": 18,
#     "types": ""
#   },
#   "heatmap": {
#     "venues_n": 0,
#     "status": "disabled",
#     "bounding_box": null,
#     "top_matches": []
#   }
# }

# %%
# Optional visualization for live heatmap data. This stays inactive when RUN_LIVE_HEATMAP is False.
try:
    import matplotlib.pyplot as plt

    first_venue = (heatmap.get("venues") or [{}])[0]
    day_raw = first_venue.get("day_raw_whole") or first_venue.get("day_raw") or []
    if day_raw:
        hours = list(range(len(day_raw)))
        plt.figure(figsize=(10, 2.8))
        plt.bar(hours, day_raw, color="#d95f02")
        plt.ylim(0, 100)
        plt.xlabel("Hour index")
        plt.ylabel("Busyness (0-100)")
        plt.title(f"BestTime heatmap sample: {first_venue.get('venue_name', 'Unknown venue')}")
        plt.tight_layout()
        plt.show()
    else:
        print("No live heatmap data loaded. Set RUN_LIVE_HEATMAP=True only when you want to spend venue filter credits.")
except ImportError:
    print("matplotlib is not installed, so the notebook only prints the JSON summary.")
# Out:
# No live heatmap data loaded. Set RUN_LIVE_HEATMAP=True only when you want to spend venue filter credits.

# %% [markdown]
# ## Query Existing Forecast
#
# This section tests BestTime query endpoints only. It requires an existing `venue_id` and `api_key_public`; it does not create a new forecast and does not call Radar / venue filter.

# %%
if not API_KEY_PUBLIC.startswith("pub_") or API_KEY_PUBLIC == "pub_paste_your_public_key_here":
    raise ValueError("Set API_KEY_PUBLIC to your real BestTime public key before running query tests.")

week = query_week(API_KEY_PUBLIC, QUERY_VENUE_ID)
week_raw = query_week_raw(API_KEY_PUBLIC, QUERY_VENUE_ID)
day = query_day(API_KEY_PUBLIC, QUERY_VENUE_ID, DAY_INT)

query_result = {
    "mode": "query_existing_forecast_only",
    "venue_id": QUERY_VENUE_ID,
    "week_status": week.get("status"),
    "week_raw_status": week_raw.get("status"),
    "day_status": day.get("status"),
    "week_keys": sorted(list(week.keys()))[:20],
    "week_raw_keys": sorted(list(week_raw.keys()))[:20],
    "day_keys": sorted(list(day.keys()))[:20],
}

print(json.dumps(query_result, indent=2, ensure_ascii=False))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 55, in get_json(url, params)
#      54 try:
# ---> 55     with urlopen(request, timeout=30) as response:
#      56         return json.loads(response.read().decode("utf-8"))
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     532 args = (dict, 'default', 'http_error_default') + orig_args
# --> 533 return self._call_chain(*args)
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     465 func = getattr(handler, meth_name)
# --> 466 result = func(*args)
#     467 if result is not None:
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 4
#       1 if not API_KEY_PUBLIC.startswith("pub_") or API_KEY_PUBLIC == "pub_paste_your_public_key_here":
#       2     raise ValueError("Set API_KEY_PUBLIC to your real BestTime public key before running query tests.")
# ----> 4 week = query_week(API_KEY_PUBLIC, QUERY_VENUE_ID)
#       5 week_raw = query_week_raw(API_KEY_PUBLIC, QUERY_VENUE_ID)
#       6 day = query_day(API_KEY_PUBLIC, QUERY_VENUE_ID, DAY_INT)
#
# Cell In[1], line 135, in query_week(api_key_public, venue_id)
#     133 def query_week(api_key_public: str, venue_id: str) -> dict:
#     134     # Query an existing forecast by venue_id. This avoids creating a new forecast.
# --> 135     return get_json(
#     136         BESTTIME_QUERY_WEEK_URL,
#     137         {
#     138             "api_key_public": api_key_public,
#     139             "venue_id": venue_id,
#     140         },
#     141     )
#
# Cell In[1], line 59, in get_json(url, params)
#      57 except HTTPError as exc:
#      58     error_body = exc.read().decode("utf-8", errors="replace")
# ---> 59     raise RuntimeError(f"BestTime HTTP {exc.code}: {error_body}") from exc
#
# RuntimeError: BestTime HTTP 400: {"status":"Error","message":"Error: API query quota reached"}

# %% [markdown]
# ## Manhattan 1 km Scenario Matrix
#
# The next section queries the same Manhattan center point with a fixed 1 km radius and compares several time windows side by side. This is a practical way to read the BestTime output as a scenario matrix instead of a single static map.

# %% [markdown]
# ## Folium Manhattan Map
#
# This version uses Leaflet through Folium, draws venue points on top of a real map, and colors each point by peak busyness. Each scenario is added as a separate overlay layer so you can compare the same Manhattan area under different time windows.

# %%
import folium
from branca.colormap import linear

# Four time windows as separate layers on one map.
FOLIUM_SCENARIOS = [
    {"label": "Mon 08-12", "day_int": 0, "hour_min": 8, "hour_max": 12},
    {"label": "Mon 12-18", "day_int": 0, "hour_min": 12, "hour_max": 18},
    {"label": "Wed 08-12", "day_int": 2, "hour_min": 8, "hour_max": 12},
    {"label": "Wed 12-18", "day_int": 2, "hour_min": 12, "hour_max": 18},
]

# BestTime heatmaps are relative scores, so a 0-100 color scale is enough.
colormap = linear.YlOrRd_09.scale(0, 100)
colormap.caption = "Peak busyness (0-100)"


def fetch_heatmap_for_scenario(day_int: int, hour_min: int, hour_max: int) -> dict:
    # Use Manhattan bounding box and paginate so each scenario can collect all venues without hitting the 500-venue ceiling.
    return fetch_manhattan_pages(
        API_KEY_PRIVATE,
        day_int,
        hour_min,
        hour_max,
        TYPES,
        limit=500,
        max_pages=10,
    )


def add_scenario_layer(map_obj, scenario: dict):
    # If the filter is too restrictive, BestTime can return no venues. That is handled by the fallback note in the layer.
    payload = fetch_heatmap_for_scenario(scenario["day_int"], scenario["hour_min"], scenario["hour_max"])
    layer = folium.FeatureGroup(name=scenario["label"], show=True)
    points = venue_points(payload)

    if not points:
        folium.Marker(
            location=[(MANHATTAN_LAT_MIN + MANHATTAN_LAT_MAX) / 2, (MANHATTAN_LNG_MIN + MANHATTAN_LNG_MAX) / 2],
            popup=f"{scenario['label']}: no venues returned",
            icon=folium.Icon(color="gray", icon="info-sign"),
        ).add_to(layer)
        layer.add_to(map_obj)
        return payload

    for point in points:
        color = colormap(point["peak"] or 0)
        popup_html = f"""
        <b>{point['name']}</b><br>
        Peak busyness: {point['peak']}<br>
        Lat/Lng: {point['lat']}, {point['lng']}
        """
        folium.CircleMarker(
            location=[point["lat"], point["lng"]],
            radius=8,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.9,
            weight=1,
            popup=folium.Popup(popup_html, max_width=300),
            tooltip=f"{point['name']} | peak {point['peak']}",
        ).add_to(layer)

    layer.add_to(map_obj)
    return payload


# Create one map centered on Manhattan and add each scenario as a toggleable layer.
map_center = folium.Map(
    location=[(MANHATTAN_LAT_MIN + MANHATTAN_LAT_MAX) / 2, (MANHATTAN_LNG_MIN + MANHATTAN_LNG_MAX) / 2],
    zoom_start=12,
    tiles="CartoDB positron",
    width="100%",
    height="720px",
)
folium.Rectangle(
    bounds=[[MANHATTAN_LAT_MIN, MANHATTAN_LNG_MIN], [MANHATTAN_LAT_MAX, MANHATTAN_LNG_MAX]],
    color="#3186cc",
    fill=False,
    weight=2,
    tooltip="Manhattan analysis bounding box",
).add_to(map_center)

scenario_payloads = {}
if not RUN_LIVE_HEATMAP:
    folium.Marker(
        location=[(MANHATTAN_LAT_MIN + MANHATTAN_LAT_MAX) / 2, (MANHATTAN_LNG_MIN + MANHATTAN_LNG_MAX) / 2],
        popup="Live BestTime venue filter is disabled to save quota.",
        icon=folium.Icon(color="gray", icon="info-sign"),
    ).add_to(map_center)
else:
    for scenario in FOLIUM_SCENARIOS:
        scenario_payloads[scenario["label"]] = add_scenario_layer(map_center, scenario)

# Fit the map to the Manhattan bounds so the tile layer fills the viewport.
map_center.fit_bounds([[MANHATTAN_LAT_MIN, MANHATTAN_LNG_MIN], [MANHATTAN_LAT_MAX, MANHATTAN_LNG_MAX]])

colormap.add_to(map_center)
folium.LayerControl(collapsed=False).add_to(map_center)
map_center
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab8f2c8b6100c8eaa11ab048bb46bef7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 720.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab8f2c8b6100c8eaa11ab048bb46bef7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab8f2c8b6100c8eaa11ab048bb46bef7 = L.map(
#                 &quot;map_ab8f2c8b6100c8eaa11ab048bb46bef7&quot;,
#                 {
#                     center: [40.791, -73.97],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec99bab578fb477ae375735cd33af66b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec99bab578fb477ae375735cd33af66b.addTo(map_ab8f2c8b6100c8eaa11ab048bb46bef7);
#
#
#             var rectangle_c6b1e2ebab525e3ec19e55775da2f41b = L.rectangle(
#                 [[40.7, -74.03], [40.882, -73.91]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ab8f2c8b6100c8eaa11ab048bb46bef7);
#
#
#             rectangle_c6b1e2ebab525e3ec19e55775da2f41b.bindTooltip(
#                 `&lt;div&gt;
#                      Manhattan analysis bounding box
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a933fdf2192700526e0b724c57bedd15 = L.marker(
#                 [40.791, -73.97],
#                 {
# }
#             ).addTo(map_ab8f2c8b6100c8eaa11ab048bb46bef7);
#
#
#             var icon_2efb002b280dc2085e549cf169788092 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;gray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8167d1e6efc21e1159e621cb653f3ae0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39128eecc1f236a70d5ba52955a7c9c3 = $(`&lt;div id=&quot;html_39128eecc1f236a70d5ba52955a7c9c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Live BestTime venue filter is disabled to save quota.&lt;/div&gt;`)[0];
#                 popup_8167d1e6efc21e1159e621cb653f3ae0.setContent(html_39128eecc1f236a70d5ba52955a7c9c3);
#
#
#
#         marker_a933fdf2192700526e0b724c57bedd15.bindPopup(popup_8167d1e6efc21e1159e621cb653f3ae0)
#         ;
#
#
#
#
#                 marker_a933fdf2192700526e0b724c57bedd15.setIcon(icon_2efb002b280dc2085e549cf169788092);
#
#
#             map_ab8f2c8b6100c8eaa11ab048bb46bef7.fitBounds(
#                 [[40.7, -74.03], [40.882, -73.91]],
#                 {}
#             );
#
#
#     var color_map_1a113c0b4f88c8294a7d65f003d38729 = {};
#
#
#     color_map_1a113c0b4f88c8294a7d65f003d38729.color = d3.scale.threshold()
#               .domain([0.0, 0.20040080160320642, 0.40080160320641284, 0.6012024048096193, 0.8016032064128257, 1.002004008016032, 1.2024048096192386, 1.402805611222445, 1.6032064128256514, 1.8036072144288577, 2.004008016032064, 2.2044088176352705, 2.404809619238477, 2.6052104208416833, 2.80561122244489, 3.006012024048096, 3.2064128256513027, 3.406813627254509, 3.6072144288577155, 3.8076152304609217, 4.008016032064128, 4.208416833667335, 4.408817635270541, 4.609218436873747, 4.809619238476954, 5.01002004008016, 5.210420841683367, 5.410821643286573, 5.61122244488978, 5.811623246492986, 6.012024048096192, 6.212424849699399, 6.412825651302605, 6.613226452905812, 6.813627254509018, 7.014028056112225, 7.214428857715431, 7.414829659318637, 7.615230460921843, 7.81563126252505, 8.016032064128256, 8.216432865731463, 8.41683366733467, 8.617234468937875, 8.817635270541082, 9.01803607214429, 9.218436873747494, 9.418837675350701, 9.619238476953909, 9.819639278557114, 10.02004008016032, 10.220440881763528, 10.420841683366733, 10.62124248496994, 10.821643286573146, 11.022044088176353
